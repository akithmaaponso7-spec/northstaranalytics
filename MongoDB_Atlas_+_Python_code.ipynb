# %% [markdown]
# <a href="https://colab.research.google.com/github/akithmaaponso7-spec/northstaranalytics/blob/main/MongoDB_Atlas_%2B_Python_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo certifi
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (2026.4.22)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.1 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 22.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.17.0

# %%
from pymongo import MongoClient
import pandas as pd
import certifi

# %%
client = MongoClient(
    "mongodb+srv://northstar:northstar123@cluster0.4rmshhz.mongodb.net/?appName=Cluster0",
    tlsCAFile=certifi.where()
)

# %%
client.list_database_names()
# Out:
# ['NorthStarDB', 'admin', 'local']

# %%
db = client["NorthStarDB"]

# %%
customers_collection = db["customers"]
orders_collection = db["orders"]
deliveries_collection = db["deliveries"]
drivers_collection = db["drivers"]
hubs_collection = db["hubs"]
complaints_collection = db["complaints"]
incidents_collection = db["incidents"]
service_events_collection = db["service_events"]
customer_service_view_collection = db["customer_service_view"]

print("Collections created successfully")
# Out:
# Collections created successfully

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
csv_files = {}

for root, dirs, files in os.walk("northstar_dataset"):
    for file in files:
        if file.endswith(".csv"):
            csv_files[file.replace(".csv", "")] = os.path.join(root, file)

csv_files
# Out:
# {}

# %%
customers_df = pd.read_csv("customers.csv")
orders_df = pd.read_csv("orders.csv")
deliveries_df = pd.read_csv("deliveries.csv")
complaints_df = pd.read_csv("complaints.csv")
drivers_df = pd.read_csv("drivers.csv")
incidents_df = pd.read_csv("incidents.csv")

# %%
customers_collection.insert_many(customers_df.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('6a00d6efbf841af2178b3556'), ObjectId('6a00d6efbf841af2178b3557'), ObjectId('6a00d6efbf841af2178b3558'), ObjectId('6a00d6efbf841af2178b3559'), ObjectId('6a00d6efbf841af2178b355a'), ObjectId('6a00d6efbf841af2178b355b'), ObjectId('6a00d6efbf841af2178b355c'), ObjectId('6a00d6efbf841af2178b355d'), ObjectId('6a00d6efbf841af2178b355e'), ObjectId('6a00d6efbf841af2178b355f'), ObjectId('6a00d6efbf841af2178b3560'), ObjectId('6a00d6efbf841af2178b3561'), ObjectId('6a00d6efbf841af2178b3562'), ObjectId('6a00d6efbf841af2178b3563'), ObjectId('6a00d6efbf841af2178b3564'), ObjectId('6a00d6efbf841af2178b3565'), ObjectId('6a00d6efbf841af2178b3566'), ObjectId('6a00d6efbf841af2178b3567'), ObjectId('6a00d6efbf841af2178b3568'), ObjectId('6a00d6efbf841af2178b3569'), ObjectId('6a00d6efbf841af2178b356a'), ObjectId('6a00d6efbf841af2178b356b'), ObjectId('6a00d6efbf841af2178b356c'), ObjectId('6a00d6efbf841af2178b356d'), ObjectId('6a00d6efbf841af2178b356e'), ObjectId('6a00d6efbf841af2178b356f'), ObjectId('6
f841af2178b42c0'), ObjectId('6a00d710bf841af2178b42c1'), ObjectId('6a00d710bf841af2178b42c2'), ObjectId('6a00d710bf841af2178b42c3'), ObjectId('6a00d710bf841af2178b42c4'), ObjectId('6a00d710bf841af2178b42c5'), ObjectId('6a00d710bf841af2178b42c6'), ObjectId('6a00d710bf841af2178b42c7'), ObjectId('6a00d710bf841af2178b42c8'), ObjectId('6a00d710bf841af2178b42c9'), ObjectId('6a00d710bf841af2178b ...

# %%
customers_collection.create_index("customer_id")

orders_collection.create_index("order_id")

deliveries_collection.create_index("delivery_id")

drivers_collection.create_index("driver_id")

complaints_collection.create_index("complaint_id")

incidents_collection.create_index("incident_id")
# Out:
# 'incident_id_1'

# %%
print("Customers:", customers_collection.count_documents({}))
print("Orders:", orders_collection.count_documents({}))
print("Deliveries:", deliveries_collection.count_documents({}))
print("Complaints:", complaints_collection.count_documents({}))
print("Drivers:", drivers_collection.count_documents({}))
print("Incidents:", incidents_collection.count_documents({}))
# Out:
# Customers: 2600
# Orders: 2500
# Deliveries: 1900
# Complaints: 640
# Drivers: 340
# Incidents: 560

# %%
list(deliveries_collection.find(
    {"delivery_status": "Delayed"},
    {"_id": 0, "delivery_id": 1, "delivery_status": 1, "customer_rating_post_delivery": 1}
).limit(5))
# Out:
# [{'delivery_id': 'DL00004',
#   'delivery_status': 'Delayed',
#   'customer_rating_post_delivery': 4.18},
#  {'delivery_id': 'DL00006',
#   'delivery_status': 'Delayed',
#   'customer_rating_post_delivery': 1.57},
#  {'delivery_id': 'DL00007',
#   'delivery_status': 'Delayed',
#   'customer_rating_post_delivery': 4.64},
#  {'delivery_id': 'DL00017',
#   'delivery_status': 'Delayed',
#   'customer_rating_post_delivery': 1.0},
#  {'delivery_id': 'DL00028',
#   'delivery_status': 'Delayed',
#   'customer_rating_post_delivery': 2.7}]

# %%
pipeline = [
    {
        "$group": {
            "_id": "$delivery_status",
            "total_deliveries": {"$sum": 1},
            "average_rating": {"$avg": "$customer_rating_post_delivery"}
        }
    }
]

list(deliveries_collection.aggregate(pipeline))
# Out:
# [{'_id': 'OnTime', 'total_deliveries': 1232, 'average_rating': nan},
#  {'_id': 'Failed', 'total_deliveries': 264, 'average_rating': nan},
#  {'_id': 'Delayed', 'total_deliveries': 404, 'average_rating': nan}]

# %%
pipeline = [
    {
        "$match": {
            "customer_rating_post_delivery": {"$type": "double"}
        }
    },
    {
        "$group": {
            "_id": "$delivery_status",
            "total_deliveries": {"$sum": 1},
            "average_rating": {"$avg": "$customer_rating_post_delivery"}
        }
    }
]

list(deliveries_collection.aggregate(pipeline))
# Out:
# [{'_id': 'Failed', 'total_deliveries': 264, 'average_rating': nan},
#  {'_id': 'OnTime', 'total_deliveries': 1232, 'average_rating': nan},
#  {'_id': 'Delayed', 'total_deliveries': 404, 'average_rating': nan}]

# %%
pipeline = [
    {
        "$match": {
            "customer_rating_post_delivery": {
                "$gte": 0
            }
        }
    },
    {
        "$group": {
            "_id": "$delivery_status",
            "total_rated_deliveries": {"$sum": 1},
            "average_rating": {"$avg": "$customer_rating_post_delivery"}
        }
    }
]

list(deliveries_collection.aggregate(pipeline))
# Out:
# [{'_id': 'OnTime',
#   'total_rated_deliveries': 1216,
#   'average_rating': 4.28327302631579},
#  {'_id': 'Failed',
#   'total_rated_deliveries': 262,
#   'average_rating': 3.0493129770992367},
#  {'_id': 'Delayed',
#   'total_rated_deliveries': 394,
#   'average_rating': 3.11497461928934}]

# %%
deliveries_collection.find(
    {"delivery_id": "DL00004"}
).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'NorthStarDB.deliveries',
#   'parsedQuery': {'delivery_id': {'$eq': 'DL00004'}},
#   'indexFilterSet': False,
#   'queryHash': '82482AA0',
#   'planCacheShapeHash': '82482AA0',
#   'planCacheKey': 'ADB49191',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'delivery_id': 1},
#     'indexName': 'delivery_id_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'delivery_id': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'delivery_id': ['["DL00004", "DL00004"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 2,
#   'executionTimeMillis': 0,
#   'totalKeysExamined': 2,
#   'totalDocsExamined': 2,
#   'executionStages': {'isCached': False,
#    'stage': 'FETCH',
#    'nReturned': 2,
#    'executionTimeMillisEstimate': 0,
#    'works': 3,
#    'advanced': 2,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'docsExamined': 2,
#    'alreadyHasObj': 0,
#    'inputStage': {'stage': 'IXSCAN',
#     'nReturned': 2,
#     'executionTimeMillisEstimate': 0,
#     'works': 3,
#     'advanced': 2,
#     'needTime': 0,
#     'needYield': 0,
#     'saveState': 0,
#     'restoreState': 0,
#     'isEOF': 1,
#     'keyPattern': {'delivery_id': 1},
#     'indexName': 'delivery_id_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'delivery_id': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'delivery_id': ['["DL00004", "DL00004"]']},
#     'keysExamined': 2,
#     'seeks': 1,
#     'dupsTested': 0,
#     'dupsDropped': 0}},
#   'allPlansExecution': []},
#  'queryShapeHash': '84F8D769DDA7FE8053BD138D8FC53E018DC276E856C1563E12E957C8697D398A',
#  'command': {'find': 'deliveries',
#   'filter': {'delivery_id': 'DL00004'},
#   '$db': 'NorthStarDB'},
#  'serverInfo': {'host': 'ac-urahhdn-shard-00-01.4rmshhz.mongodb.net',
#   'port': 27017,
#   'version': '8.0.23',
#   'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 16793600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 33554432,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1778440012, 3),
#   'signature': {'hash': b'\xd1\xa7\xe9\t\x00>\xa6\xd4\xbdv\xe3\xee+\xc1h3\xdaL\xc1\x07',
#    'keyId': 7592264223724404749}},
#  'operationTime': Timestamp(1778440012, 3)}

# %%
list(
    deliveries_collection.find(
        {},
        {
            "_id": 0,
            "delivery_id": 1,
            "customer_rating_post_delivery": 1,
            "delivery_status": 1
        }
    )
    .sort("customer_rating_post_delivery", -1)
    .limit(5)
)
# Out:
# [{'delivery_id': 'DL00002',
#   'delivery_status': 'OnTime',
#   'customer_rating_post_delivery': 5.0},
#  {'delivery_id': 'DL00016',
#   'delivery_status': 'OnTime',
#   'customer_rating_post_delivery': 5.0},
#  {'delivery_id': 'DL00045',
#   'delivery_status': 'OnTime',
#   'customer_rating_post_delivery': 5.0},
#  {'delivery_id': 'DL00025',
#   'delivery_status': 'OnTime',
#   'customer_rating_post_delivery': 5.0},
#  {'delivery_id': 'DL00023',
#   'delivery_status': 'OnTime',
#   'customer_rating_post_delivery': 5.0}]

# %%
list(
    deliveries_collection.find(
        {
            "delivery_status": "Delayed",
            "manual_route_override_count": {"$gte": 2}
        },
        {
            "_id": 0,
            "delivery_id": 1,
            "delivery_status": 1,
            "manual_route_override_count": 1,
            "customer_rating_post_delivery": 1
        }
    ).limit(5)
)
# Out:
# [{'delivery_id': 'DL00028',
#   'delivery_status': 'Delayed',
#   'manual_route_override_count': 2,
#   'customer_rating_post_delivery': 2.7},
#  {'delivery_id': 'DL00055',
#   'delivery_status': 'Delayed',
#   'manual_route_override_count': 5,
#   'customer_rating_post_delivery': 2.78},
#  {'delivery_id': 'DL00059',
#   'delivery_status': 'Delayed',
#   'manual_route_override_count': 3,
#   'customer_rating_post_delivery': 3.11},
#  {'delivery_id': 'DL00077',
#   'delivery_status': 'Delayed',
#   'manual_route_override_count': 3,
#   'customer_rating_post_delivery': 2.81},
#  {'delivery_id': 'DL00127',
#   'delivery_status': 'Delayed',
#   'manual_route_override_count': 2,
#   'customer_rating_post_delivery': 2.12}]

# %%
deliveries_collection.create_index([
    ("delivery_status", 1),
    ("manual_route_override_count", 1)
])
# Out:
# 'delivery_status_1_manual_route_override_count_1'

# %%
deliveries_collection.update_one(
    {"delivery_id": "DL00028"},
    {"$set": {"delivery_status": "Resolved"}}
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000089'), 'opTime': {'ts': Timestamp(1778440071, 2), 't': 137}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778440071, 2), 'signature': {'hash': b'\xb8@\x80\x18\xa0\xa5\x03\x89\x8bG\xae\xd9\xc9\xd1\x08\xb4,\xdb@\xf7', 'keyId': 7592264223724404749}}, 'operationTime': Timestamp(1778440071, 2), 'updatedExisting': True}, acknowledged=True)

# %%
list(
    deliveries_collection.find(
        {"delivery_id": "DL00028"},
        {
            "_id": 0,
            "delivery_id": 1,
            "delivery_status": 1
        }
    )
)
# Out:
# [{'delivery_id': 'DL00028', 'delivery_status': 'Resolved'},
#  {'delivery_id': 'DL00028', 'delivery_status': 'Delayed'}]

# %%
deliveries_collection.delete_one(
    {"delivery_id": "DL00028"}
)
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000089'), 'opTime': {'ts': Timestamp(1778440100, 9), 't': 137}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778440100, 9), 'signature': {'hash': b'\x1f\tT}|e\xee\xd6\xed(zc\x8bR\xcb\xf3\x8c\xc3\xc3f', 'keyId': 7592264223724404749}}, 'operationTime': Timestamp(1778440100, 9)}, acknowledged=True)

# %%
list(
    deliveries_collection.find(
        {"delivery_id": "DL00028"},
        {"_id": 0, "delivery_id": 1, "delivery_status": 1}
    )
)
# Out:
# [{'delivery_id': 'DL00028', 'delivery_status': 'Delayed'}]

# %%
deliveries_collection.insert_one({
    "delivery_id": "DL00028",
    "delivery_status": "Delayed",
    "manual_route_override_count": 2,
    "customer_rating_post_delivery": 2.7
})
# Out:
# InsertOneResult(ObjectId('6a00d7bdbf841af2178b437a'), acknowledged=True)

# %%
pipeline = [
    {
        "$lookup": {
            "from": "incidents",
            "localField": "delivery_id",
            "foreignField": "delivery_id",
            "as": "incident_details"
        }
    },
    {
        "$match": {
            "incident_details": {"$ne": []}
        }
    },
    {
        "$project": {
            "_id": 0,
            "delivery_id": 1,
            "delivery_status": 1,
            "incident_details.incident_type": 1,
            "incident_details.severity": 1
        }
    }
]

list(deliveries_collection.aggregate(pipeline))[:5]
# Out:
# [{'delivery_id': 'DL00001',
#   'delivery_status': 'Failed',
#   'incident_details': [{'incident_type': 'ProofMissing', 'severity': 'High'},
#    {'incident_type': 'ProofMissing', 'severity': 'High'}]},
#  {'delivery_id': 'DL00009',
#   'delivery_status': 'OnTime',
#   'incident_details': [{'incident_type': 'AppSyncError', 'severity': 'Low'},
#    {'incident_type': 'BatteryAlert', 'severity': 'Medium'},
#    {'incident_type': 'AppSyncError', 'severity': 'Low'},
#    {'incident_type': 'BatteryAlert', 'severity': 'Medium'}]},
#  {'delivery_id': 'DL00011',
#   'delivery_status': 'OnTime',
#   'incident_details': [{'incident_type': 'ProofMissing', 'severity': 'Medium'},
#    {'incident_type': 'ProofMissing', 'severity': 'Medium'}]},
#  {'delivery_id': 'DL00013',
#   'delivery_status': 'OnTime',
#   'incident_details': [{'incident_type': 'VehicleFault', 'severity': 'Medium'},
#    {'incident_type': 'VehicleFault', 'severity': 'Medium'}]},
#  {'delivery_id': 'DL00014',
#   'delivery_status': 'OnTime',
#   'incident_details': [{'incident_type': 'ProofMissing', 'severity': 'High'},
#    {'incident_type': 'ProofMissing', 'severity': 'High'}]}]
